# %% [markdown]
# # BT02: Khám phá dữ liệu, tiền xử lý, phân tích đơn giản
# (Cập nhật 14/11/2020)
#
# Họ tên: Nguyễn Tấn Thìn
#
# MSSV: 18120085

# %% [markdown]
# ---

# %% [markdown]
# ## Cách làm bài và nộp bài
# &#9889; Bạn lưu ý là mình sẽ dùng chương trình hỗ trợ chấm bài nên bạn cần phải tuân thủ chính xác qui định mà mình đặt ra, nếu không rõ thì hỏi, chứ không nên tự tiện làm theo ý của cá nhân.
#
# **Cách làm bài**
#
# Bạn sẽ làm trực tiếp trên file notebook này. Đầu tiên, bạn điền họ tên và MSSV vào phần đầu file ở bên trên. Trong file, bạn làm bài ở những chỗ có ghi là:
# ```python
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
# hoặc đối với những phần code không bắt buộc thì là:
# ```python
# # YOUR CODE HERE (OPTION)
# ```
# hoặc đối với markdown cell thì là:
# ```markdown
# YOUR ANSWER HERE
# ```
# Tất nhiên, khi làm thì bạn xóa dòng `raise NotImplementedError()` đi.
# Đối những phần yêu cầu code thì thường ở ngay phía dưới sẽ có một (hoặc một số) cell chứa các bộ test để giúp bạn biết đã code đúng hay chưa; nếu chạy cell này không có lỗi gì thì có nghĩa là qua được các bộ test. Trong một số trường hợp, các bộ test có thể sẽ không đầy đủ; nghĩa là, nếu không qua được test thì là code sai, nhưng nếu qua được test thì chưa chắc đã đúng.
#
# Trong khi làm bài, bạn có thể cho in ra màn hình, tạo thêm các cell để test. Nhưng khi nộp bài thì bạn xóa các cell mà bạn tự tạo, xóa hoặc comment các câu lệnh in ra màn hình. Bạn lưu ý <font color=red>không được tự tiện xóa các cell hay sửa code của Thầy</font> (trừ những chỗ được phép sửa như đã nói ở trên).
#
# Trong khi làm bài, thường xuyên `Ctrl + S` để lưu lại bài làm của bạn, tránh mất mát thông tin.
#
#
# *Nên nhớ mục tiêu chính ở đây là <font color=green>học, học một cách chân thật</font>. Bạn có thể thảo luận ý tưởng với bạn khác, nhưng <font color=green>code và bài làm phải là của bạn, dựa trên sự hiểu thật sự của bạn</font>. <font color=red>Nếu vi phạm thì sẽ bị 0 điểm cho toàn bộ môn học.</font>*
#
# **Cách nộp bài**
#
# Khi chấm bài, đầu tiên mình sẽ chọn `Kernel` - `Restart & Run All`, để restart và chạy tất cả các cell trong notebook của bạn; do đó, trước khi nộp bài, bạn nên chạy thử `Kernel` - `Restart & Run All` để đảm bảo mọi chuyện diễn ra đúng như mong đợi.
#
# Sau đó, bạn tạo thư mục nộp bài theo cấu trúc sau:
# - Thư mục `MSSV` (vd, nếu bạn có MSSV là 1234567 thì bạn đặt tên thư mục là `1234567`)
#     - File `BT02-KhamPha_TienXuLy_PhanTich.ipynb` (không cần nộp các file khác)
#
# Cuối cùng, bạn nén thư mục `MSSV` này lại và nộp ở link trên moodle. <font color=red>Bạn lưu ý tuân thủ chính xác cấu trúc này.</font>

# %% [markdown]
# ---

# %% [markdown]
# ## Import

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
# YOUR CODE HERE (OPTION) 
# Nếu cần các thư viện khác thì bạn có thể import ở đây

# %% [markdown]
# ---

# %% [markdown]
# ## Thu thập dữ liệu

# %% [markdown]
# Dữ liệu được sử dụng trong bài tập này là dữ liệu khảo sát các lập trình viên của trang StackOverflow. Mình download dữ liệu [ở đây](https://drive.google.com/file/d/1dfGerWeWkcyQ9GX9x20rdSGj7WtEpzBB/view) và có bỏ đi một số cột để đơn giản hóa.
#
# Theo mô tả trong file "README_2020.txt" của StackOverflow:
# >The enclosed data set is the full, cleaned results of the 2020 Stack Overflow Developer Survey. Free response submissions and personally identifying information have been removed from the results to protect the privacy of respondents. There are three files besides this README:
# >
# >1. survey_results_public.csv - CSV file with main survey results, one respondent per row and one column per answer
# >2. survey_results_schema.csv - CSV file with survey schema, i.e., the questions that correspond to each column name
# >3. so_survey_2020.pdf - PDF file of survey instrument
# >
# >The survey was fielded from February 5 to February 28, 2020. The median time spent on the survey for qualified responses was 16.6 minutes.
# >
# >Respondents were recruited primarily through channels owned by Stack Overflow. The top 5 sources of respondents were onsite messaging, blog posts, email lists, Meta posts, banner ads, and social media posts. Since respondents were recruited in this way, highly engaged users on Stack Overflow were more likely to notice the links for the survey and click to begin it.
#
# File "survey_results_public-short.csv" mà mình đính kèm là phiên bản đơn giản hóa của file "survey_results_public.csv" (từ 61 cột, mình bỏ xuống còn 29 cột). Đây là file dữ liệu chính mà bạn sẽ làm trong bài tập này. Ngoài ra, mình còn đính kèm 2 file phụ: (1) file "survey_results_schema-short.csv" là file cho biết ý nghĩa của các cột, và (2) file "so_survey_2020.pdf" là file khảo sát gốc của StackOverflow.
#
# Để ý:
# - Dữ liệu này không đại diện được cho cộng đồng lập trình viên trên toàn thế giới, mà chỉ giới hạn trong tập những lập trình viên thực hiện khảo sát của StackOverflow. Những câu trả lời có được thông qua tập dữ liệu này cũng sẽ bị giới hạn trong phạm vi đó.
# - Dữ liệu có đúng không? Về cơ bản là ta không biết được. Ở đây, mục đích chính là học qui trình Khoa Học Dữ Liệu và các câu lệnh của Pandas nên ta sẽ **giả định** phần lớn dữ liệu là đúng và tiếp tục làm.
#
# Cũng theo file "README_2020.txt", dữ liệu này được StackOverflow public với license như sau:
# >This database - The Public 2020 Stack Overflow Developer Survey Results - is made available under the Open Database License (ODbL): http://opendatacommons.org/licenses/odbl/1.0/. Any rights in individual contents of the database are licensed under the Database Contents License: http://opendatacommons.org/licenses/dbcl/1.0/
# >
# >TLDR: You are free to share, adapt, and create derivative works from The Public 2020 Stack Overflow Developer Survey Results as long as you attribute Stack Overflow, keep the database open (if you redistribute it), and continue to share-alike any adapted database under the ODbl.

# %% [markdown]
# ---

# %% [markdown]
# ## Khám phá dữ liệu

# %% [markdown]
# ### Đọc dữ liệu từ file (0.25đ)

# %% [markdown]
# Đầu tiên, bạn viết code để đọc dữ liệu từ file "survey_results_public-short.csv" và lưu kết quả vào DataFrame `survey_df`. Ngoài ra, bạn cũng cần cho cột `Respondent` (id của người làm khảo sát) làm cột index của `survey_df`.

# %%
# YOUR CODE HERE
survey_df = pd.read_csv("survey_results_public-short.csv", index_col="Respondent")

# %%
# TEST
survey_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#             ConvertedComp             Country  \
# Respondent
# 1                     NaN             Germany
# 2                     NaN      United Kingdom
# 3                     NaN  Russian Federation
# 4                     NaN             Albania
# 5                     NaN       United States
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
#
#                                Ethnicity Gender  ...  \
# Respondent                                       ...
# 1           White or of European descent    Man  ...
# 2                                    NaN    NaN  ...
# 3                                    NaN    NaN  ...
# 4           White or of European descent    Man  ...
# 5           White or of European descent    Man  ...
#
#                                      NEWEdImpt       NEWLearn  \
# Respondent
# 1                             Fairly important    Once a year
# 2                             Fairly important    Once a year
# 3                                          NaN  Once a decade
# 4           Not at all important/not necessary    Once a year
# 5                               Very important    Once a year
#
#                                                   NEWOvertime  \
# Respondent
# 1                            Often: 1-2 days per week or more
# 2                                                         NaN
# 3                                                         NaN
# 4           Occasionally: 1-2 days per quarter but less th...
# 5                                                         NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                         PlatformWorkedWith WorkWeekHrs YearsCode YearsCodePro
# Respondent
# 1                                  Windows        50.0        36           27
# 2                                      iOS         NaN         7            4
# 3                                      NaN         NaN         4          NaN
# 4                                      NaN        40.0         7            4
# 5           AWS;Docker;Linux;MacOS;Windows         NaN        15            8
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Dữ liệu có bao nhiêu dòng và bao nhiêu cột? (0.25đ)

# %% [markdown]
# Kế đến, bạn tính số dòng và số cột của DataFrame `survey_df` và lưu vào biến `shape` (tuple).

# %%
# YOUR CODE HERE
shape = survey_df.shape

# %%
# TEST
assert shape == (64461, 28)

# %% [markdown]
# ### Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Theo file "README_2020.txt" cũng như theo quan sát sơ bộ về dữ liệu, mỗi dòng trong DataFrame `survey_df` cho biết kết quả làm khảo sát của một người. Có vẻ không có vấn đề các dòng có ý nghĩa khác nhau (lúc sau, nếu phát hiện ra vấn đề thì ta sẽ quay lại đây).

# %% [markdown]
# ### Dữ liệu có các dòng bị lặp không? (0.25đ)

# %% [markdown]
# Kế đến, bạn tính số dòng có index (id của người làm khảo sát) bị lặp và lưu vào biến `num_duplicated_rows`. Trong nhóm các dòng có index giống nhau thì dòng đầu tiên không tính là bị lặp.

# %%
# YOUR CODE HERE
num_duplicated_rows = survey_df.index.duplicated().sum()

# %%
# TEST
assert num_duplicated_rows == 0

# %% [markdown]
# ### Mỗi cột có ý nghĩa gì? (0.25đ)

# %% [markdown]
# Để xem ý nghĩa của mỗi cột thì:
# - Trước tiên, bạn cần đọc file "survey_results_schema-short.csv" vào DataFrame `col_meaning_df`; bạn cũng cần cho cột "Column" làm cột index.
# - Sau đó, bạn chỉ cần hiển thị DataFrame `col_meaning_df` ra để xem (vụ này khó nên ở dưới mình đã làm cho bạn ở cell có dòng "# TEST" 😉). Tuy nhiên, bạn sẽ thấy ở cột "QuestionText": các chuỗi mô tả bị cắt do quá dài. Do đó, trước khi hiển thị DataFrame `col_meaning_df`, bạn cũng cần chỉnh sao đó để các chuỗi mô tả không bị cắt (vụ này bạn tự search Google, gợi ý: bạn sẽ dùng đến câu lệnh `pd.set_option`).

# %%
# YOUR CODE HERE
col_meaning_df = pd.read_csv("survey_results_schema-short.csv", index_col="Column")
pd.set_option('display.max_colwidth', None)

# %%
# TEST
col_meaning_df
# Out:
#                                                                                                                                                                                                                                                                                                     QuestionText
# Column
# Respondent                                                                                                                                                                                                                                Randomized respondent ID number (not in order of survey response time)
# MainBranch                                                                                                                                                                                      Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."
# Hobbyist                                                                                                                                                                                                                                                                                 Do you code as a hobby?
# Age                                                                                                                                                                                                                 What is your age (in years)? If you prefer not to answer, you may leave this question blank.
# ConvertedComp                                                                                                                                                                    Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.
# Country                                                                                                                                                                                                                                                                                       Where do you live?
# DevType                                                                                                                                                                                                                                       Which of the following describe you? Please select all that apply.
# EdLevel                                                                                                                                                                                                       Which of the following best describes the highest level of formal education that you’ve completed?
# Employment                                                                                                                                                                                                                                 Which of the following best describes your current employment status?
# Ethnicity                                                                                                                                                              Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
# Gender                                                                                                                                                                 Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
# JobFactors                                                                                                                                 Imagine that you are deciding between two job offers with the same compensation, benefits, and location. Of the following factors, which 3 are MOST important to you?
# JobSat                                                                                                                                                                                 How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)
# LanguageDesireNextYear        Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# LanguageWorkedWith            Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# MiscTechDesireNextYear             Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# MiscTechWorkedWith                 Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# NEWCollabToolsDesireNextYear                                    Which collaboration tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you worked with the tool and want to continue to do so, please check both boxes in that row.)
# NEWCollabToolsWorkedWith                                        Which collaboration tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you worked with the tool and want to continue to do so, please check both boxes in that row.)
# NEWEdImpt                                                                                                                                                                                                  How important is a formal education, such as a university degree in computer science, to your career?
# NEWLearn                                                                                                                                                                                                                                                How frequently do you learn a new language or framework?
# NEWOvertime                                                                                                                                                                                                                    How often do you work overtime or beyond the formal time expectation of your job?
# NEWStuck                                                                                                                                                                                                                                  What do you do when you get stuck on a problem? Select all that apply.
# OpSys                                                                                                                                                                                                                                                    What is the primary operating system in which you work?
# PlatformDesireNextYear                                           Which platforms have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
# PlatformWorkedWith                                               Which platforms have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
# WorkWeekHrs                                                                                                                                                                                                             On average, how many hours per week do you work? Please enter a whole number in the box.
# YearsCode                                                                                                                                                                                                                                 Including any education, how many years have you been coding in total?
# YearsCodePro                                                                                                                                                                                                     NOT including education, how many years have you coded professionally (as a part of your work)?

# %% [markdown]
# Trước khi đi tiếp, bạn nên đọc kết quả hiển thị ở trên và đảm bảo là bạn đã hiểu ý nghĩa của các cột. Để hiểu ý nghĩa của cột, có thể bạn sẽ cần xem thêm các giá trị của cột bên DataFrame `survey_df`.

# %% [markdown]
# ### Mỗi cột hiện đang có kiểu dữ liệu gì? Có cột nào có kiểu dữ liệu chưa phù hợp để có thể xử lý tiếp không? (0.25đ)

# %% [markdown]
# Kế đến, bạn tính kiểu dữ liệu (dtype) của mỗi cột trong DataFrame `survey_df` và lưu kết quả vào Series `dtypes` (Series này có index là tên cột).

# %%
# YOUR CODE HERE
dtypes = survey_df.dtypes
dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# ConvertedComp                   float64
# Country                          object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# MiscTechWorkedWith               object
# NEWCollabToolsDesireNextYear     object
# NEWCollabToolsWorkedWith         object
# NEWEdImpt                        object
# NEWLearn                         object
# NEWOvertime                      object
# NEWStuck                         object
# OpSys                            object
# PlatformDesireNextYear           object
# PlatformWorkedWith               object
# WorkWeekHrs                     float64
# YearsCode                        object
# YearsCodePro                     object
# dtype: object

# %%
#nhap
set(dtypes[(dtypes==np.float32) | (dtypes==np.float64)].index)
# Out:
# {'Age', 'ConvertedComp', 'WorkWeekHrs'}

# %%
#nhap
len(set(dtypes[dtypes == object].index))
# Out:
# 25

# %%
# TEST
float_cols = set(dtypes[(dtypes==np.float32) | (dtypes==np.float64)].index)
assert float_cols == {'Age', 'ConvertedComp', 'WorkWeekHrs'}
object_cols = set(dtypes[dtypes == object].index)
assert len(object_cols) == 25

# %% [markdown]
# Như bạn có thể thấy, cột "YearsCode" và "YearsCodePro" nên có kiểu dữ liệu số, nhưng hiện giờ đang có kiểu dữ liệu object. Ta hãy thử xem thêm về các giá trị 2 cột này.

# %%
survey_df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
survey_df['YearsCodePro'].unique()
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %% [markdown]
# Ta nên đưa 2 cột này về dạng số để có thể tiếp tục khám phá (tính min, median, max, ...).

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (0.5đ)

# %% [markdown]
# Bạn sẽ thực hiện tiền xử lý để chuyển 2 cột "YearsCode" và "YearsCodePro" về dạng số (float). Trong đó: "Less than 1 year" $\to$ 0, "More than 50 years" $\to$ 51. Sau khi chuyển thì `survey_df.dtypes` sẽ thay đổi.

# %%
#nhap
survey_df = pd.read_csv("survey_results_public-short.csv", index_col="Respondent")

# %%
#nhap
survey_df.YearsCode.unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
#nhap
survey_df.YearsCodePro.unique()
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %%
# YOUR CODE HERE
survey_df.YearsCode.replace({'Less than 1 year': '0', 'More than 50 years': '51'}, inplace=True)
survey_df.YearsCodePro.replace({'Less than 1 year': '0', 'More than 50 years': '51'}, inplace=True)

survey_df.YearsCode = pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df.YearsCodePro = pd.to_numeric(survey_df.YearsCodePro, errors='coerce')
survey_df.dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# ConvertedComp                   float64
# Country                          object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# MiscTechWorkedWith               object
# NEWCollabToolsDesireNextYear     object
# NEWCollabToolsWorkedWith         object
# NEWEdImpt                        object
# NEWLearn                         object
# NEWOvertime                      object
# NEWStuck                         object
# OpSys                            object
# PlatformDesireNextYear           object
# PlatformWorkedWith               object
# WorkWeekHrs                     float64
# YearsCode                       float64
# YearsCodePro                    float64
# dtype: object

# %%
# TEST
assert survey_df['YearsCode'].dtype in [np.float32, np.float64]
assert survey_df['YearsCodePro'].dtype in [np.float32, np.float64]

# %% [markdown]
# ---

# %% [markdown]
# ## Quay lại bước khám phá dữ liệu

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng số, các giá trị được phân bố như thế nào? (1đ)
#
# (Trong đó: phần tính các mô tả của mỗi cột chiếm 0.5đ, phần tính số lượng giá trị không hợp lệ của mỗi cột chiếm 0.5đ)

# %% [markdown]
# Với các cột có kiểu dữ liệu số, bạn sẽ tính:
# - Tỉ lệ % (từ 0 đến 100) các giá trị thiếu
# - Giá trị min
# - Giá trị lower quartile (phân vị 25)
# - Giá trị median (phân vị 50)
# - Giá trị upper quartile (phân vị 75)
# - Giá trị max
#
# Bạn sẽ lưu kết quả vào DataFrame `num_col_info_df`, trong đó:
# - Tên của các cột là tên của các cột số trong `survey_df`
# - Tên của các dòng là: "missing_ratio", "min", "lower_quartile", "median", "upper_quartile", "max"
#
# Để dễ nhìn, tất cả các giá trị bạn đều làm tròn với 1 chữ số thập phân bằng phương thức `.round(1)`.

# %%
# YOUR CODE HERE
df = survey_df.select_dtypes(exclude='object') # chỉ lấy kiểu numeric, ko lấy kiểu object
def missing_ratio(df):
    return df.isna().mean() * 100
def lower_quartile(df):
    return df.quantile(0.25)
def median(df):
    return df.quantile(0.5)
def upper_quartile(df):
    return df.quantile(0.75)
# Trong phương thức agg, bạn có thể truyền vào một list các
# hàm (có thể là các hàm có sẵn hoặc các hàm tự định nghĩa)
num_col_info_df = df.agg([missing_ratio, min, lower_quartile, median, upper_quartile, max]).round(1)
num_col_info_df
# Out:
#                   Age  ConvertedComp  WorkWeekHrs  YearsCode  YearsCodePro
# missing_ratio    29.5           46.1         36.2       10.5          28.1
# min               1.0            0.0          1.0        0.0           0.0
# lower_quartile   24.0        24648.0         40.0        6.0           3.0
# median           29.0        54049.0         40.0       10.0           6.0
# upper_quartile   35.0        95000.0         44.0       17.0          12.0
# max             279.0      2000000.0        475.0       51.0          51.0

# %%
# TEST
assert num_col_info_df.shape == (6, 5)
data = num_col_info_df.loc[['missing_ratio', 'min', 'lower_quartile', 'median', 'upper_quartile', 'max'],
                           ['Age', 'ConvertedComp', 'WorkWeekHrs', 'YearsCode', 'YearsCodePro']].values
correct_data = np.array([[     29.5,      46.1,      36.2,      10.5,      28.1],
                         [      1. ,       0. ,       1. ,       0. ,       0. ],
                         [     24. ,   24648. ,      40. ,       6. ,       3. ],
                         [     29. ,   54049. ,      40. ,      10. ,       6. ],
                         [     35. ,   95000. ,      44. ,      17. ,      12. ],
                         [    279. , 2000000. ,     475. ,      51. ,      51. ]])
assert np.array_equal(data, correct_data)

# %% [markdown]
# **Có giá trị không hợp lệ trong mỗi cột không? (không xét giá trị thiếu)**
# - Cột "Age": bạn hãy tính số lượng giá trị không hợp lệ của cột "Age" (< giá trị tương ứng trong cột "YearsCode" HOẶC < giá trị tương ứng trong cột "YearsCodePro") và lưu kết quả vào biến `num_invalid_Age_vals`.
# - Cột "WorkWeekHrs" (số giờ làm việc trung bình một tuần): ta thấy max là 475 giờ! Trong khi đó, 7 ngày * 24 giờ = 168 giờ! Bạn hãy tính số lượng giá trị không hợp lệ của cột "WorkWeekHrs" (> 24 * 7) và lưu kết quả vào biến `num_invalid_WorkWeekHrs`.
# - Cột "YearsCode": bạn hãy tính số lượng giá trị không hợp lệ của cột "YearsCode" (< giá trị tương ứng trong cột "YearsCodePro" HOẶC > giá trị tương ứng trong cột "Age") và lưu kết quả vào biến `num_invalid_YearsCode`.
# - Cột "YearsCodePro": bạn hãy tính số lượng giá trị không hợp lệ của cột "YearsCodePro" (> giá trị tương ứng trong cột "YearsCode" HOẶC > giá trị tương ứng trong cột "Age") và lưu kết quả vào biến `num_invalid_YearsCodePro`.

# %%
#nhap
num_invalid_WorkWeekHrs_vals = (survey_df['WorkWeekHrs'] > 24*7).sum()
num_invalid_WorkWeekHrs_vals
# Out:
# 62

# %%
#nhap
num_invalid_Age_vals = ((survey_df['Age'] < survey_df['YearsCode']) | (survey_df['Age'] < survey_df['YearsCodePro'])).sum()
num_invalid_Age_vals
# Out:
# 16

# %%
#nhap
num_invalid_YearsCode_vals = ((survey_df['YearsCode'] < survey_df['YearsCodePro']) | (survey_df['YearsCode'] > survey_df['Age'])).sum()
num_invalid_YearsCode_vals
# Out:
# 499

# %%
#nhap
num_invalid_YearsCodePro_vals = ((survey_df['YearsCodePro'] > survey_df['YearsCode']) | (survey_df['YearsCodePro'] > survey_df['Age'])).sum()
num_invalid_YearsCodePro_vals
# Out:
# 486

# %%
# YOUR CODE HERE
num_invalid_WorkWeekHrs_vals = (survey_df['WorkWeekHrs'] > 24*7).sum()
num_invalid_Age_vals = ((survey_df['Age'] < survey_df['YearsCode']) | (survey_df['Age'] < survey_df['YearsCodePro'])).sum()
num_invalid_YearsCode_vals = ((survey_df['YearsCode'] < survey_df['YearsCodePro']) | (survey_df['YearsCode'] > survey_df['Age'])).sum()
num_invalid_YearsCodePro_vals = ((survey_df['YearsCodePro'] > survey_df['YearsCode']) | (survey_df['YearsCodePro'] > survey_df['Age'])).sum()

# %%
# TEST
assert num_invalid_WorkWeekHrs_vals == 62
assert num_invalid_Age_vals == 16
assert num_invalid_YearsCode_vals == 499
assert num_invalid_YearsCodePro_vals == 486

# %% [markdown]
# Do số lượng các giá trị không hợp lệ cũng khá ít nên ta có thể tiền xử lý bằng cách xóa các dòng chứa các giá trị không hợp lệ.

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (0.5đ)

# %% [markdown]
# Bạn sẽ thực hiện tiền xử lý để xóa đi các dòng của DataFrame `survey_df` mà chứa ít nhất là một giá trị không hợp lệ. Sau khi tiền xử lý thì `survey_df` sẽ thay đổi.

# %%
#nhap
bool_series = (survey_df['WorkWeekHrs'] > 24*7) | (survey_df['Age'] < survey_df['YearsCode']) | (survey_df['Age'] < survey_df['YearsCodePro']) \
| (survey_df['YearsCode'] < survey_df['YearsCodePro'])
invalid_row_index = survey_df[bool_series].index
invalid_row_index
# Out:
# Int64Index([  322,   513,  1048,  1335,  1364,  1518,  1794,  1897,  2226,
#              2318,
#             ...
#             29507, 30156, 37306, 38854, 49805, 55074, 55815, 57084, 58819,
#             61983],
#            dtype='int64', name='Respondent', length=561)

# %%
#nhap
survey_df.drop(invalid_row_index, errors='ignore')
# Out:
#                                                           MainBranch Hobbyist  \
# Respondent
# 1                                     I am a developer by profession      Yes
# 2                                     I am a developer by profession       No
# 3                                        I code primarily as a hobby      Yes
# 4                                     I am a developer by profession      Yes
# 5           I used to be a developer by profession, but no longer am      Yes
# ...                                                              ...      ...
# 64858                                                            NaN      Yes
# 64867                                                            NaN      Yes
# 64898                                                            NaN      Yes
# 64925                                                            NaN      Yes
# 65112                                                            NaN      Yes
#
#              Age  ConvertedComp             Country  \
# Respondent
# 1            NaN            NaN             Germany
# 2            NaN            NaN      United Kingdom
# 3            NaN            NaN  Russian Federation
# 4           25.0            NaN             Albania
# 5           31.0            NaN       United States
# ...          ...            ...                 ...
# 64858        NaN            NaN       United States
# 64867        NaN            NaN             Morocco
# 64898        NaN            NaN            Viet Nam
# 64925        NaN            NaN              Poland
# 65112        NaN            NaN               Spain
#
#                                                                         DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;Developer, full-stack
# 2                                       Developer, full-stack;Developer, mobile
# 3                                                                           NaN
# 4                                                                           NaN
# 5                                                                           NaN
# ...                                                                         ...
# 64858                                                       Senior executive/VP
# 64867                                                                       NaN
# 64898                                                                       NaN
# 64925                                                                       NaN
# 65112                                                                       NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 64858       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64867                                                   NaN
# 64898                             Primary/elementary school
# 64925                                                   NaN
# 65112            Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                                       Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-employed
# 2                                             Employed full-time
# 3                                                            NaN
# 4                                                            NaN
# 5                                             Employed full-time
# ...                                                          ...
# 64858                                         Employed full-time
# 64867                                         Employed full-time
# 64898                                                        NaN
# 64925                                         Employed full-time
# 65112                                         Employed full-time
#
#                                Ethnicity Gender  ...  \
# Respondent                                       ...
# 1           White or of European descent    Man  ...
# 2                                    NaN    NaN  ...
# 3                                    NaN    NaN  ...
# 4           White or of European descent    Man  ...
# 5           White or of European descent    Man  ...
# ...                                  ...    ...  ...
# 64858                                NaN    NaN  ...
# 64867                                NaN    NaN  ...
# 64898                                NaN    NaN  ...
# 64925                                NaN    NaN  ...
# 65112                                NaN    NaN  ...
#
#                                      NEWEdImpt       NEWLearn  \
# Respondent
# 1                             Fairly important    Once a year
# 2                             Fairly important    Once a year
# 3                                          NaN  Once a decade
# 4           Not at all important/not necessary    Once a year
# 5                               Very important    Once a year
# ...                                        ...            ...
# 64858                           Very important  Once a decade
# 64867                                      NaN            NaN
# 64898                                      NaN            NaN
# 64925                                      NaN    Once a year
# 65112                     Critically important    Once a year
#
#                                                          NEWOvertime  \
# Respondent
# 1                                   Often: 1-2 days per week or more
# 2                                                                NaN
# 3                                                                NaN
# 4           Occasionally: 1-2 days per quarter but less than monthly
# 5                                                                NaN
# ...                                                              ...
# 64858                                                            NaN
# 64867                                                            NaN
# 64898                                                            NaN
# 64925                                                            NaN
# 65112                                                            NaN
#
#                                                                                                                                                                   NEWStuck  \
# Respondent
# 1                                                                          Visit Stack Overflow;Go for a walk or other physical activity;Do other work and come back later
# 2                                                                                                            Visit Stack Overflow;Go for a walk or other physical activity
# 3                                                                                                                                                                      NaN
# 4                                                                                                                                                                      NaN
# 5           Call a coworker or friend;Visit Stack Overflow;Watch help / tutorial videos;Do other work and come back later;Visit another developer community (please name):
# ...                                                                                                                                                                    ...
# 64858                                                                                                                                            Call a coworker or friend
# 64867                                                                                                                                                                  NaN
# 64898                                                                                                                                                                  NaN
# 64925                                                                                                                       Call a coworker or friend;Visit Stack Overflow
# 65112                                Meditate;Visit Stack Overflow;Go for a walk or other physical activity;Watch help / tutorial videos;Do other work and come back later
#
#                   OpSys                             PlatformDesireNextYear  \
# Respondent
# 1               Windows     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                 MacOS                         iOS;Kubernetes;Linux;MacOS
# 3           Linux-based                                                NaN
# 4           Linux-based                                                NaN
# 5               Windows  Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                 ...                                                ...
# 64858           Windows                                                NaN
# 64867               NaN                                                NaN
# 64898               NaN                                                NaN
# 64925           Windows                                                NaN
# 65112           Windows                 Arduino;Linux;Raspberry Pi;Windows
#
#                                     PlatformWorkedWith WorkWeekHrs YearsCode  \
# Respondent
# 1                                              Windows        50.0      36.0
# 2                                                  iOS         NaN       7.0
# 3                                                  NaN         NaN       4.0
# 4                                                  NaN        40.0       7.0
# 5                       AWS;Docker;Linux;MacOS;Windows         NaN      15.0
# ...                                                ...         ...       ...
# 64858                                              NaN         NaN      10.0
# 64867                                              NaN         NaN       NaN
# 64898                                              NaN         NaN       NaN
# 64925                                    Linux;Windows         NaN       NaN
# 65112       Android;Arduino;Linux;Raspberry Pi;Windows         NaN       NaN
#
#            YearsCodePro
# Respondent
# 1                  27.0
# 2                   4.0
# 3                   NaN
# 4                   4.0
# 5                   8.0
# ...                 ...
# 64858               0.0
# 64867               NaN
# 64898               NaN
# 64925               NaN
# 65112               NaN
#
# [63900 rows x 28 columns]

# %%
# YOUR CODE HERE
bool_series = (survey_df['WorkWeekHrs'] > 24*7) \
| (survey_df['Age'] < survey_df['YearsCode']) \
| (survey_df['Age'] < survey_df['YearsCodePro']) \
| (survey_df['YearsCode'] < survey_df['YearsCodePro'])

invalid_row_index = survey_df[bool_series].index
survey_df.drop(invalid_row_index, errors='ignore', inplace=True)

# %%
# TEST
assert len(survey_df) == 63900

# %% [markdown]
# ---

# %% [markdown]
# ## Quay lại bước khám phá dữ liệu

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu không phải dạng số, các giá trị được phân bố như thế nào? (1đ)

# %% [markdown]
# Với các cột có kiểu dữ liệu không phải số, bạn sẽ tính:
# - Tỉ lệ % (từ 0 đến 100) các giá trị thiếu
# - Số lượng các giá trị (các giá trị ở đây là các giá trị khác nhau và ta không xét giá trị thiếu): với cột mà ứng với câu hỏi dạng multichoice (ví dụ, cột "DevType"), mỗi giá trị có thể chứa nhiều choice (các choice được phân tách bởi dấu chấm phẩy), và việc đếm trực tiếp các giá trị không có nhiều ý nghĩa lắm vì số lượng tổ hợp các choice là khá nhiều; một cách khác tốt hơn mà bạn sẽ làm là đếm số lượng các choice
# - Tỉ lệ % (từ 0 đến 100) của mỗi giá trị được sort theo tỉ lệ % giảm dần (ta không xét giá trị thiếu, tỉ lệ là tỉ lệ so với số lượng các giá trị không thiếu): bạn dùng dictionary để lưu, key là giá trị, value là tỉ lệ %; với cột mà ứng với câu hỏi dạng multichoice, cách làm tương tự như ở trên
#
# Bạn sẽ lưu kết quả vào DataFrame `cat_col_info_df`, trong đó:
# - Tên của các cột là tên của các cột không phải số trong `survey_df`
# - Tên của các dòng là: "missing_ratio", "num_values", "value_ratios"
#
# Để dễ nhìn, tất cả các giá trị bạn đều làm tròn với 1 chữ số thập phân bằng phương thức `.round(1)`.
#
# Gợi ý: có thể bạn sẽ muốn dùng [phương thức `explode`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.explode.html).

# %%
# Các cột ứng với câu hỏi khảo sát multichoice
multichoice_cols = ['DevType', 'Gender', 'JobFactors', 
                    'LanguageWorkedWith', 'LanguageDesireNextYear', 
                    'MiscTechWorkedWith', 'MiscTechDesireNextYear', 
                    'NEWCollabToolsWorkedWith', 'NEWCollabToolsDesireNextYear', 
                    'PlatformWorkedWith', 'PlatformDesireNextYear', 
                    'NEWStuck']

# %%
pd.set_option('display.max_colwidth', 100) # Để dễ nhìn
pd.set_option('display.max_columns', None) # Để dễ nhìn
# YOUR CODE HERE
#nhap
df = survey_df.select_dtypes(include='object')
def missing_ratio(df):
    return (df.isna().mean() * 100).round(1)

def num_values(col):
    if col.name not in multichoice_cols:
        return col.nunique()
    else:
        s = col.str.split(';').explode()
        return s.nunique()
    
def value_ratios(col):
    if col.name not in multichoice_cols:
        return dict((col.value_counts(normalize=True)*100).round(1))
    else:
        s = col.str.split(';').explode()
        s = (s.value_counts(normalize=True, ascending=False)*100).round(1)
        return dict(s)
    
cat_col_info_df = df.agg([missing_ratio, num_values, value_ratios])
cat_col_info_df
# Out:
#                                                                                                         MainBranch  \
# missing_ratio                                                                                                  0.5
# num_values                                                                                                       5
# value_ratios   {'I am a developer by profession': 73.5, 'I am a student who is learning to code': 12.5, 'I am n...
#
#                                 Hobbyist  \
# missing_ratio                        0.1
# num_values                             2
# value_ratios   {'Yes': 78.2, 'No': 21.8}
#
#                                                                                                            Country  \
# missing_ratio                                                                                                  0.6
# num_values                                                                                                     183
# value_ratios   {'United States': 19.5, 'India': 13.0, 'United Kingdom': 6.1, 'Germany': 6.1, 'Canada': 3.4, 'Fr...
#
#                                                                                                            DevType  \
# missing_ratio                                                                                                 23.6
# num_values                                                                                                      23
# value_ratios   {'Developer, back-end': 17.4, 'Developer, full-stack': 17.3, 'Developer, front-end': 11.7, 'Deve...
#
#                                                                                                            EdLevel  \
# missing_ratio                                                                                                   11
# num_values                                                                                                       9
# value_ratios   {'Bachelor’s degree (B.A., B.S., B.Eng., etc.)': 46.3, 'Master’s degree (M.A., M.S., M.Eng., MBA...
#
#                                                                                                         Employment  \
# missing_ratio                                                                                                  0.9
# num_values                                                                                                       7
# value_ratios   {'Employed full-time': 70.8, 'Student': 12.3, 'Independent contractor, freelancer, or self-emplo...
#
#                                                                                                          Ethnicity  \
# missing_ratio                                                                                                 28.6
# num_values                                                                                                     204
# value_ratios   {'White or of European descent': 64.0, 'South Asian': 9.7, 'Hispanic or Latino/a/x': 4.9, 'Black...
#
#                                                                                               Gender  \
# missing_ratio                                                                                   21.5
# num_values                                                                                         3
# value_ratios   {'Man': 90.8, 'Woman': 7.9, 'Non-binary, genderqueer, or gender non-conforming': 1.2}
#
#                                                                                                         JobFactors  \
# missing_ratio                                                                                                 23.4
# num_values                                                                                                      11
# value_ratios   {'Languages, frameworks, and other technologies I’d be working with': 17.5, 'Office environment ...
#
#                                                                                                             JobSat  \
# missing_ratio                                                                                                 30.1
# num_values                                                                                                       5
# value_ratios   {'Very satisfied': 32.4, 'Slightly satisfied': 30.9, 'Slightly dissatisfied': 15.8, 'Neither sat...
#
#                                                                                             LanguageDesireNextYear  \
# missing_ratio                                                                                                   16
# num_values                                                                                                      25
# value_ratios   {'Python': 11.2, 'JavaScript': 11.0, 'HTML/CSS': 8.7, 'SQL': 8.4, 'TypeScript': 7.2, 'C#': 5.7, ...
#
#                                                                                                 LanguageWorkedWith  \
# missing_ratio                                                                                                   11
# num_values                                                                                                      25
# value_ratios   {'JavaScript': 13.5, 'HTML/CSS': 12.6, 'SQL': 10.9, 'Python': 8.8, 'Java': 8.0, 'Bash/Shell/Powe...
#
#                                                                                             MiscTechDesireNextYear  \
# missing_ratio                                                                                                 34.3
# num_values                                                                                                      19
# value_ratios   {'Node.js': 17.0, 'TensorFlow': 10.1, '.NET Core': 9.6, 'React Native': 8.4, '.NET': 6.9, 'Flutt...
#
#                                                                                                 MiscTechWorkedWith  \
# missing_ratio                                                                                                 37.5
# num_values                                                                                                      19
# value_ratios   {'Node.js': 23.1, '.NET': 15.7, '.NET Core': 12.0, 'Pandas': 7.0, 'TensorFlow': 5.2, 'React Nati...
#
#                                                                                       NEWCollabToolsDesireNextYear  \
# missing_ratio                                                                                                 26.6
# num_values                                                                                                      11
# value_ratios   {'Github': 24.7, 'Slack': 14.1, 'Gitlab': 11.3, 'Google Suite (Docs, Meet, etc)': 10.6, 'Jira': ...
#
#                                                                                           NEWCollabToolsWorkedWith  \
# missing_ratio                                                                                                   18
# num_values                                                                                                      11
# value_ratios   {'Github': 22.2, 'Slack': 14.2, 'Jira': 12.8, 'Google Suite (Docs, Meet, etc)': 11.1, 'Gitlab': ...
#
#                                                                                                          NEWEdImpt  \
# missing_ratio                                                                                                   25
# num_values                                                                                                       5
# value_ratios   {'Fairly important': 26.2, 'Very important': 24.4, 'Somewhat important': 23.5, 'Not at all impor...
#
#                                                                                                           NEWLearn  \
# missing_ratio                                                                                                 12.9
# num_values                                                                                                       4
# value_ratios   {'Every few months': 37.3, 'Once a year': 36.9, 'Once every few years': 23.7, 'Once a decade': 2.2}
#
#                                                                                                        NEWOvertime  \
# missing_ratio                                                                                                 33.1
# num_values                                                                                                       5
# value_ratios   {'Sometimes: 1-2 days per month but less than weekly': 26.7, 'Often: 1-2 days per week or more':...
#
#                                                                                                           NEWStuck  \
# missing_ratio                                                                                                 14.7
# num_values                                                                                                       9
# value_ratios   {'Visit Stack Overflow': 26.7, 'Do other work and come back later': 16.1, 'Watch help / tutorial...
#
#                                                                            OpSys  \
# missing_ratio                                                               12.8
# num_values                                                                     4
# value_ratios   {'Windows': 48.3, 'Linux-based': 26.6, 'MacOS': 25.1, 'BSD': 0.1}
#
#                                                                                             PlatformDesireNextYear  \
# missing_ratio                                                                                                 21.5
# num_values                                                                                                      16
# value_ratios   {'Linux': 14.3, 'Docker': 12.2, 'AWS': 9.6, 'Windows': 9.3, 'Android': 7.9, 'Kubernetes': 7.3, '...
#
#                                                                                                 PlatformWorkedWith
# missing_ratio                                                                                                 16.5
# num_values                                                                                                      16
# value_ratios   {'Linux': 16.6, 'Windows': 16.0, 'Docker': 10.6, 'AWS': 8.1, 'Android': 7.9, 'MacOS': 7.2, 'Rasp...

# %%
#nhap
df.agg([missing_ratio, num_values, value_ratios])[['MainBranch', 'Hobbyist', 'DevType', 'PlatformWorkedWith']]
# Out:
#                                                                                                         MainBranch  \
# missing_ratio                                                                                                  0.5
# num_values                                                                                                       5
# value_ratios   {'I am a developer by profession': 73.5, 'I am a student who is learning to code': 12.5, 'I am n...
#
#                                 Hobbyist  \
# missing_ratio                        0.1
# num_values                             2
# value_ratios   {'Yes': 78.2, 'No': 21.8}
#
#                                                                                                            DevType  \
# missing_ratio                                                                                                 23.6
# num_values                                                                                                      23
# value_ratios   {'Developer, back-end': 17.4, 'Developer, full-stack': 17.3, 'Developer, front-end': 11.7, 'Deve...
#
#                                                                                                 PlatformWorkedWith
# missing_ratio                                                                                                 16.5
# num_values                                                                                                      16
# value_ratios   {'Linux': 16.6, 'Windows': 16.0, 'Docker': 10.6, 'AWS': 8.1, 'Android': 7.9, 'MacOS': 7.2, 'Rasp...

# %%
#nhap
cat_col_info_df.loc['value_ratios', 'DevType']
# Out:
# {'Developer, back-end': 17.4,
#  'Developer, full-stack': 17.3,
#  'Developer, front-end': 11.7,
#  'Developer, desktop or enterprise applications': 7.5,
#  'Developer, mobile': 6.0,
#  'DevOps specialist': 3.8,
#  'Database administrator': 3.6,
#  'Designer': 3.4,
#  'System administrator': 3.3,
#  'Developer, embedded applications or devices': 3.0,
#  'Data or business analyst': 2.5,
#  'Data scientist or machine learning specialist': 2.5,
#  'Developer, QA or test': 2.5,
#  'Engineer, data': 2.4,
#  'Academic researcher': 2.2,
#  'Educator': 1.9,
#  'Developer, game or graphics': 1.8,
#  'Engineering manager': 1.7,
#  'Product manager': 1.6,
#  'Scientist': 1.3,
#  'Engineer, site reliability': 1.2,
#  'Senior executive/VP': 0.8,
#  'Marketing or sales professional': 0.4}

# %%
#nhap
cat_col_info_df.loc['value_ratios', 'PlatformWorkedWith']
# Out:
# {'Linux': 16.6,
#  'Windows': 16.0,
#  'Docker': 10.6,
#  'AWS': 8.1,
#  'Android': 7.9,
#  'MacOS': 7.2,
#  'Raspberry Pi': 4.5,
#  'Microsoft Azure': 4.4,
#  'WordPress': 4.3,
#  'Google Cloud Platform': 4.2,
#  'iOS': 3.7,
#  'Kubernetes': 3.5,
#  'Heroku': 3.3,
#  'Arduino': 3.2,
#  'Slack Apps and Integrations': 2.2,
#  'IBM Cloud or Watson': 0.5}

# %%
# TEST
c = cat_col_info_df['MainBranch']
assert c.loc['missing_ratio'] == 0.5
assert c.loc['num_values'] == 5
assert c.loc['value_ratios']['I am a developer by profession'] == 73.5

c = cat_col_info_df['Hobbyist']
assert c.loc['missing_ratio'] == 0.1
assert c.loc['num_values'] == 2
assert c.loc['value_ratios']['Yes'] == 78.2

c = cat_col_info_df['DevType']
assert c.loc['missing_ratio'] == 23.6
assert c.loc['num_values'] == 23
assert c.loc['value_ratios']['Academic researcher'] == 2.2

c = cat_col_info_df['PlatformWorkedWith']
assert c.loc['missing_ratio'] == 16.5
assert c.loc['num_values'] == 16
assert c.loc['value_ratios']['Docker'] == 10.6

# %% [markdown]
# ---

# %% [markdown]
# ## Đặt câu hỏi

# %% [markdown]
# Sau khi khám phá dữ liệu, ta đã hiểu hơn về dữ liệu. Bây giờ, ta hãy xem thử có câu hỏi nào có thể được trả lời bằng dữ liệu này.
#
# **Một câu hỏi có thể có là:** Platform nào (Windows, Linux, Docker, AWS, ...) được yêu thích nhất, platform nào được yêu thích nhì, platform nào được yêu thích ba, ...?
#
# Một platform được xem là được yêu thích nếu một người đã dùng platform này (cột "PlatformWorkedWith") và muốn tiếp tục dùng platform trong năm kế (cột "PlatformDesireNextYear").
#
# **Trả lời được câu hỏi này sẽ** phần nào giúp ta định hướng là nên tập trung học platform nào để có thể chuẩn bị cho tương lai (mình nói "phần nào" vì ở đây dữ liệu chỉ giới hạn trong phạm vi những người làm khảo sát của StackOverflow).

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý

# %% [markdown]
# Nếu bạn thấy cần thực hiện thêm thao tác tiền xử lý để chuẩn bị dữ liệu cho bước phân tích thì bạn làm ở đây. Bước này là không bắt buộc.

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ---

# %% [markdown]
# ## Phân tích dữ liệu (2.25đ)

# %% [markdown]
# Bây giờ, bạn sẽ thực hiện phân tích dữ liệu để trả lời cho câu hỏi ở trên. Cụ thể các bước như sau:
# - Bước 1: tính Series `most_loved_platforms`, trong đó:
#     - Index là tên flatform (ở bước khám phá dữ liệu, bạn đã thấy có tất cả 16 platform)
#     - Data là tỉ lệ % (từ 0 đến 100, được làm tròn với một chữ số thập phân bằng phương thức `round(1)`) được yêu thích (được sort giảm dần)
# - Bước 2: từ Series `most_loved_platforms`, bạn vẽ bar chart:
#     - Bạn cho các bar nằm ngang (cho dễ nhìn)
#     - Bạn đặt tên trục hoành là "Tỉ lệ %"

# %% [markdown]
# Code bước 1.

# %%
#nhap
survey_df[['PlatformDesireNextYear', 'PlatformWorkedWith']].head(10)
# Out:
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# 6                                                     Android
# 7                                                         NaN
# 8                             iOS;Slack Apps and Integrations
# 9                                                         NaN
# 10                         Android;Linux;Raspberry Pi;Windows
#
#                             PlatformWorkedWith
# Respondent
# 1                                      Windows
# 2                                          iOS
# 3                                          NaN
# 4                                          NaN
# 5               AWS;Docker;Linux;MacOS;Windows
# 6                     Android;Docker;WordPress
# 7                                          NaN
# 8                                       Docker
# 9                                    WordPress
# 10          Android;Linux;Raspberry Pi;Windows

# %%
#nhap
df = survey_df[['PlatformDesireNextYear', 'PlatformWorkedWith']]
df = df.apply(lambda col: col.str.split(';'))
df = df.explode('PlatformWorkedWith').explode('PlatformDesireNextYear')
df
# Out:
#            PlatformDesireNextYear PlatformWorkedWith
# Respondent
# 1                         Android            Windows
# 1                             iOS            Windows
# 1                      Kubernetes            Windows
# 1                 Microsoft Azure            Windows
# 1                         Windows            Windows
# ...                           ...                ...
# 65112                     Windows       Raspberry Pi
# 65112                     Arduino            Windows
# 65112                       Linux            Windows
# 65112                Raspberry Pi            Windows
# 65112                     Windows            Windows
#
# [763997 rows x 2 columns]

# %%
# YOUR CODE HERE
df = survey_df[['PlatformDesireNextYear', 'PlatformWorkedWith']]
df = df.apply(lambda col: col.str.split(';'))
df = df.explode('PlatformWorkedWith').explode('PlatformDesireNextYear')
df = df[df.PlatformWorkedWith == df.PlatformDesireNextYear]
most_loved_platforms = (df.PlatformWorkedWith.value_counts(normalize=True, ascending=False) * 100).round(1)
most_loved_platforms
# Out:
# Linux                          20.2
# Windows                        14.6
# Docker                         12.3
# AWS                             8.5
# MacOS                           7.4
# Android                         7.1
# Raspberry Pi                    4.7
# Microsoft Azure                 4.3
# Google Cloud Platform           4.1
# Kubernetes                      3.9
# iOS                             3.5
# Arduino                         2.7
# Heroku                          2.4
# WordPress                       2.2
# Slack Apps and Integrations     1.8
# IBM Cloud or Watson             0.3
# Name: PlatformWorkedWith, dtype: float64

# %%
# TEST
assert len(most_loved_platforms) == 16
assert most_loved_platforms.loc['Linux'] == 20.2
assert most_loved_platforms.loc['Windows'] == 14.6
assert most_loved_platforms.loc['Docker'] == 12.3

# %% [markdown]
# Code bước 2.

# %%
# YOUR CODE HERE
most_loved_platforms.plot.barh()
plt.xlabel('Tỉ lệ %')
# Out:
# Text(0.5, 0, 'Tỉ lệ %')

# %% [markdown]
# Bạn đã hiểu tại sao mình khuyên bạn là nên tập làm quen dần với các câu lệnh của Linux chưa 😉

# %% [markdown]
# ---

# %% [markdown]
# ## Đặt câu hỏi của bạn (1.5đ)

# %% [markdown]
# Bây giờ, đến lượt bạn phải tự suy nghĩ và đưa ra câu hỏi mà có thể trả lời bằng dữ liệu. Ngoài việc đưa ra câu hỏi, bạn cũng phải giải thích để người đọc thấy nếu trả lời được câu hỏi thì sẽ có lợi ích gì. Bạn không nên đưa ra câu hỏi cùng dạng với câu hỏi của mình ở trên.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý để chuẩn bị dữ liệu cho bước phân tích để trả lời cho câu hỏi của bạn

# %% [markdown]
# Phần này là không bắt buộc.

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ---

# %% [markdown]
# ## Phân tích dữ liệu để ra câu trả lời cho câu hỏi của bạn (2đ)

# %%
#nhap
df = survey_df[['MainBranch', 'JobFactors']]
df = df.dropna()
df
# Out:
#                                 MainBranch  \
# Respondent
# 1           I am a developer by profession
# 4           I am a developer by profession
# 6           I am a developer by profession
# 8           I am a developer by profession
# 9           I am a developer by profession
# ...                                    ...
# 65623       I am a developer by profession
# 65625       I am a developer by profession
# 65627       I am a developer by profession
# 65629       I am a developer by profession
# 65630       I am a developer by profession
#
#                                                                                                      JobFactors
# Respondent
# 1           Languages, frameworks, and other technologies I’d be working with;Remote work options;Opportunit...
# 4           Flex time or a flexible schedule;Office environment or company culture;Opportunities for profess...
# 6           Diversity of the company or organization;Languages, frameworks, and other technologies I’d be wo...
# 8                            Remote work options;Opportunities for professional development;Family friendliness
# 9            Diversity of the company or organization;Remote work options;Office environment or company culture
# ...                                                                                                         ...
# 65623       Specific department or team I’d be working on;Office environment or company culture;Opportunitie...
# 65625       Industry that I’d be working in;Languages, frameworks, and other technologies I’d be working wit...
# 65627       Flex time or a flexible schedule;Languages, frameworks, and other technologies I’d be working wi...
# 65629       Flex time or a flexible schedule;Languages, frameworks, and other technologies I’d be working wi...
# 65630       Languages, frameworks, and other technologies I’d be working with;Remote work options;Office env...
#
# [48940 rows x 2 columns]

# %%
#nhap
df.isna().sum()
# Out:
# MainBranch    0
# JobFactors    0
# dtype: int64

# %%
#nhap
df.describe()
# Out:
#                             MainBranch  \
# count                            48940
# unique                               3
# top     I am a developer by profession
# freq                             38203
#
#                                                                                                  JobFactors
# count                                                                                                 48940
# unique                                                                                                  230
# top     Flex time or a flexible schedule;Languages, frameworks, and other technologies I’d be working wi...
# freq                                                                                                   2754

# %%
#nhap
df.MainBranch.value_counts(normalize=True)
# Out:
# I am a developer by profession                                                   0.780609
# I am a student who is learning to code                                           0.132407
# I am not primarily a developer, but I write code sometimes as part of my work    0.086984
# Name: MainBranch, dtype: float64

# %%
df.dtypes
# Out:
# MainBranch    object
# JobFactors    object
# dtype: object

# %%
#nhap
df['JobFactors'] = df['JobFactors'].apply(lambda x: str(x).split(';'))
#df = df.explode('JobFactors')
#df.JobFactors.value_counts(normalize=True, ascending=False)
df
# Out:
#                                 MainBranch  \
# Respondent
# 1           I am a developer by profession
# 4           I am a developer by profession
# 6           I am a developer by profession
# 8           I am a developer by profession
# 9           I am a developer by profession
# ...                                    ...
# 65623       I am a developer by profession
# 65625       I am a developer by profession
# 65627       I am a developer by profession
# 65629       I am a developer by profession
# 65630       I am a developer by profession
#
#                                                                                                      JobFactors
# Respondent
# 1           [Languages, frameworks, and other technologies I’d be working with, Remote work options, Opportu...
# 4           [Flex time or a flexible schedule, Office environment or company culture, Opportunities for prof...
# 6           [Diversity of the company or organization, Languages, frameworks, and other technologies I’d be ...
# 8                        [Remote work options, Opportunities for professional development, Family friendliness]
# 9           [Diversity of the company or organization, Remote work options, Office environment or company cu...
# ...                                                                                                         ...
# 65623       [Specific department or team I’d be working on, Office environment or company culture, Opportuni...
# 65625       [Industry that I’d be working in, Languages, frameworks, and other technologies I’d be working w...
# 65627       [Flex time or a flexible schedule, Languages, frameworks, and other technologies I’d be working ...
# 65629       [Flex time or a flexible schedule, Languages, frameworks, and other technologies I’d be working ...
# 65630       [Languages, frameworks, and other technologies I’d be working with, Remote work options, Office ...
#
# [48940 rows x 2 columns]

# %%
#nhap
df = df.explode('JobFactors')
df
# Out:
#                                 MainBranch  \
# Respondent
# 1           I am a developer by profession
# 1           I am a developer by profession
# 1           I am a developer by profession
# 4           I am a developer by profession
# 4           I am a developer by profession
# ...                                    ...
# 65629       I am a developer by profession
# 65629       I am a developer by profession
# 65630       I am a developer by profession
# 65630       I am a developer by profession
# 65630       I am a developer by profession
#
#                                                                    JobFactors
# Respondent
# 1           Languages, frameworks, and other technologies I’d be working with
# 1                                                         Remote work options
# 1                                  Opportunities for professional development
# 4                                            Flex time or a flexible schedule
# 4                                       Office environment or company culture
# ...                                                                       ...
# 65629       Languages, frameworks, and other technologies I’d be working with
# 65629                                                     Remote work options
# 65630       Languages, frameworks, and other technologies I’d be working with
# 65630                                                     Remote work options
# 65630                                   Office environment or company culture
#
# [143610 rows x 2 columns]

# %%
df.JobFactors.isna().sum()
# Out:
# 0

# %%
#nhap
df[df.MainBranch=='I am a developer by profession'].JobFactors.value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1709, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [nan]                                                                                                                                                     0.182631
# [Flex time or a flexible schedule, Languages, frameworks, and other technologies I’d be working with, Remote work options]                                0.051049
# [Flex time or a flexible schedule, Languages, frameworks, and other technologies I’d be working with, Office environment or company culture]              0.046706
# [Languages, frameworks, and other technologies I’d be working with, Office environment or company culture, Opportunities for professional development]    0.045529
# [Flex time or a flexible schedule, Languages, frameworks, and other technologies I’d be working with, Opportunities for professional development]         0.029440
#                                                                                                                                                             ...
# [Diversity of the company or organization, Family friendliness]                                                                                           0.000021
# [Diversity of the company or organization, Remote work options]                                                                                           0.000021
# [Diversity of the company or organization, Specific department or team I’d be working on]                                                                 0.000021
# [Diversity of the company or organization, Financial performance or funding status of the company or organization]                                        0.000021
# [Specific department or team I’d be working on, Remote work options]                                                                                      0.000021
# Name: JobFactors, Length: 231, dtype: float64

# %%
#nhap
df[df.MainBranch=='I am a student who is learning to code'].JobFactors.value_counts(normalize=True)
# Out:
# Languages, frameworks, and other technologies I’d be working with         0.152120
# Opportunities for professional development                                0.147570
# Office environment or company culture                                     0.130374
# Flex time or a flexible schedule                                          0.121826
# Remote work options                                                       0.081634
# nan                                                                       0.074335
# How widely used or impactful my work output would be                      0.073685
# Industry that I’d be working in                                           0.065387
# Specific department or team I’d be working on                             0.043991
# Financial performance or funding status of the company or organization    0.043191
# Family friendliness                                                       0.040192
# Diversity of the company or organization                                  0.025695
# Name: JobFactors, dtype: float64

# %%
#nhap
survey_df
# Out:
#                                                           MainBranch Hobbyist  \
# Respondent
# 1                                     I am a developer by profession      Yes
# 2                                     I am a developer by profession       No
# 3                                        I code primarily as a hobby      Yes
# 4                                     I am a developer by profession      Yes
# 5           I used to be a developer by profession, but no longer am      Yes
# ...                                                              ...      ...
# 64858                                                            NaN      Yes
# 64867                                                            NaN      Yes
# 64898                                                            NaN      Yes
# 64925                                                            NaN      Yes
# 65112                                                            NaN      Yes
#
#              Age  ConvertedComp             Country  \
# Respondent
# 1            NaN            NaN             Germany
# 2            NaN            NaN      United Kingdom
# 3            NaN            NaN  Russian Federation
# 4           25.0            NaN             Albania
# 5           31.0            NaN       United States
# ...          ...            ...                 ...
# 64858        NaN            NaN       United States
# 64867        NaN            NaN             Morocco
# 64898        NaN            NaN            Viet Nam
# 64925        NaN            NaN              Poland
# 65112        NaN            NaN               Spain
#
#                                                                         DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;Developer, full-stack
# 2                                       Developer, full-stack;Developer, mobile
# 3                                                                           NaN
# 4                                                                           NaN
# 5                                                                           NaN
# ...                                                                         ...
# 64858                                                       Senior executive/VP
# 64867                                                                       NaN
# 64898                                                                       NaN
# 64925                                                                       NaN
# 65112                                                                       NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 64858       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64867                                                   NaN
# 64898                             Primary/elementary school
# 64925                                                   NaN
# 65112            Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                                       Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-employed
# 2                                             Employed full-time
# 3                                                            NaN
# 4                                                            NaN
# 5                                             Employed full-time
# ...                                                          ...
# 64858                                         Employed full-time
# 64867                                         Employed full-time
# 64898                                                        NaN
# 64925                                         Employed full-time
# 65112                                         Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
# ...                                  ...    ...
# 64858                                NaN    NaN
# 64867                                NaN    NaN
# 64898                                NaN    NaN
# 64925                                NaN    NaN
# 65112                                NaN    NaN
#
#                                                                                                      JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies I’d be working with;Remote work options;Opportunit...
# 2                                                                                                           NaN
# 3                                                                                                           NaN
# 4           Flex time or a flexible schedule;Office environment or company culture;Opportunities for profess...
# 5                                                                                                           NaN
# ...                                                                                                         ...
# 64858                                                                                                       NaN
# 64867                                                                                                       NaN
# 64898                                                                                                       NaN
# 64925                                                                                                       NaN
# 65112                                                                                                       NaN
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
# ...                           ...
# 64858                         NaN
# 64867                         NaN
# 64898                         NaN
# 64925                         NaN
# 65112                         NaN
#
#                                                                                          LanguageDesireNextYear  \
# Respondent
# 1                                                                                        C#;HTML/CSS;JavaScript
# 2                                                                                                  Python;Swift
# 3                                                                                      Objective-C;Python;Swift
# 4                                                                                                           NaN
# 5                                                                                               Java;Ruby;Scala
# ...                                                                                                         ...
# 64858                                                                                                       NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;Go;Haskell;HTML/CSS;Java;JavaScript;Julia;Kotlin;Ob...
# 64898                                                                                                       NaN
# 64925                                                                                  HTML/CSS;Java;JavaScript
# 65112                                                                           C#;HTML/CSS;Java;JavaScript;SQL
#
#                                                                                              LanguageWorkedWith  \
# Respondent
# 1                                                                                        C#;HTML/CSS;JavaScript
# 2                                                                                              JavaScript;Swift
# 3                                                                                      Objective-C;Python;Swift
# 4                                                                                                           NaN
# 5                                                                                             HTML/CSS;Ruby;SQL
# ...                                                                                                         ...
# 64858                                                                                                       NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;Go;Haskell;HTML/CSS;Java;JavaScript;Julia;Kotlin;Ob...
# 64898                                                                                                       NaN
# 64925                                                                                                  HTML/CSS
# 65112                                                                           C#;HTML/CSS;Java;JavaScript;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# ...                                      ...                ...
# 64858                                    NaN                NaN
# 64867                                    NaN                NaN
# 64898                                    NaN                NaN
# 64925                                Node.js                NaN
# 65112                      .NET Core;Xamarin     .NET;.NET Core
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# ...                                            ...
# 64858                                          NaN
# 64867                                          NaN
# 64898                                          NaN
# 64925                                Github;Gitlab
# 65112                       Github;Microsoft Teams
#
#                                                NEWCollabToolsWorkedWith  \
# Respondent
# 1                          Confluence;Jira;Slack;Microsoft Azure;Trello
# 2                                   Confluence;Jira;Github;Gitlab;Slack
# 3                                                                   NaN
# 4                                                                   NaN
# 5           Confluence;Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# ...                                                                 ...
# 64858                                                               NaN
# 64867                                                               NaN
# 64898                                                               NaN
# 64925                             Confluence;Jira;Slack;Microsoft Teams
# 65112                                                            Github
#
#                                      NEWEdImpt       NEWLearn  \
# Respondent
# 1                             Fairly important    Once a year
# 2                             Fairly important    Once a year
# 3                                          NaN  Once a decade
# 4           Not at all important/not necessary    Once a year
# 5                               Very important    Once a year
# ...                                        ...            ...
# 64858                           Very important  Once a decade
# 64867                                      NaN            NaN
# 64898                                      NaN            NaN
# 64925                                      NaN    Once a year
# 65112                     Critically important    Once a year
#
#                                                          NEWOvertime  \
# Respondent
# 1                                   Often: 1-2 days per week or more
# 2                                                                NaN
# 3                                                                NaN
# 4           Occasionally: 1-2 days per quarter but less than monthly
# 5                                                                NaN
# ...                                                              ...
# 64858                                                            NaN
# 64867                                                            NaN
# 64898                                                            NaN
# 64925                                                            NaN
# 65112                                                            NaN
#
#                                                                                                        NEWStuck  \
# Respondent
# 1               Visit Stack Overflow;Go for a walk or other physical activity;Do other work and come back later
# 2                                                 Visit Stack Overflow;Go for a walk or other physical activity
# 3                                                                                                           NaN
# 4                                                                                                           NaN
# 5           Call a coworker or friend;Visit Stack Overflow;Watch help / tutorial videos;Do other work and co...
# ...                                                                                                         ...
# 64858                                                                                 Call a coworker or friend
# 64867                                                                                                       NaN
# 64898                                                                                                       NaN
# 64925                                                            Call a coworker or friend;Visit Stack Overflow
# 65112       Meditate;Visit Stack Overflow;Go for a walk or other physical activity;Watch help / tutorial vid...
#
#                   OpSys                             PlatformDesireNextYear  \
# Respondent
# 1               Windows     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                 MacOS                         iOS;Kubernetes;Linux;MacOS
# 3           Linux-based                                                NaN
# 4           Linux-based                                                NaN
# 5               Windows  Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                 ...                                                ...
# 64858           Windows                                                NaN
# 64867               NaN                                                NaN
# 64898               NaN                                                NaN
# 64925           Windows                                                NaN
# 65112           Windows                 Arduino;Linux;Raspberry Pi;Windows
#
#                                     PlatformWorkedWith  WorkWeekHrs  \
# Respondent
# 1                                              Windows         50.0
# 2                                                  iOS          NaN
# 3                                                  NaN          NaN
# 4                                                  NaN         40.0
# 5                       AWS;Docker;Linux;MacOS;Windows          NaN
# ...                                                ...          ...
# 64858                                              NaN          NaN
# 64867                                              NaN          NaN
# 64898                                              NaN          NaN
# 64925                                    Linux;Windows          NaN
# 65112       Android;Arduino;Linux;Raspberry Pi;Windows          NaN
#
#             YearsCode  YearsCodePro
# Respondent
# 1                36.0          27.0
# 2                 7.0           4.0
# 3                 4.0           NaN
# 4                 7.0           4.0
# 5                15.0           8.0
# ...               ...           ...
# 64858            10.0           0.0
# 64867             NaN           NaN
# 64898             NaN           NaN
# 64925             NaN           NaN
# 65112             NaN           NaN
#
# [63900 rows x 28 columns]

# %%
#nhap
df = survey_df[['MainBranch', 'JobFactors']]
df = df.dropna()
df['JobFactors'] = df['JobFactors'].apply(lambda x: str(x).split(';'))
df = df.explode('JobFactors')
most_job_factor_profession = (df[df.MainBranch=='I am a developer by profession'].JobFactors.value_counts(normalize=True, ascending=False)*100).round(1)
most_job_factor_profession
# Out:
# Languages, frameworks, and other technologies I’d be working with         18.4
# Office environment or company culture                                     15.4
# Flex time or a flexible schedule                                          15.2
# Opportunities for professional development                                13.7
# Remote work options                                                       11.8
# How widely used or impactful my work output would be                       6.8
# Industry that I’d be working in                                            4.8
# Family friendliness                                                        4.0
# Financial performance or funding status of the company or organization     3.9
# Specific department or team I’d be working on                              3.8
# Diversity of the company or organization                                   2.2
# Name: JobFactors, dtype: float64

# %%
#nhap
most_job_factor_student = (df[df.MainBranch=='I am a student who is learning to code'].JobFactors.value_counts(normalize=True, ascending=False)*100).round(1)
most_job_factor_student
# Out:
# Languages, frameworks, and other technologies I’d be working with         16.4
# Opportunities for professional development                                15.9
# Office environment or company culture                                     14.1
# Flex time or a flexible schedule                                          13.2
# Remote work options                                                        8.8
# How widely used or impactful my work output would be                       8.0
# Industry that I’d be working in                                            7.1
# Specific department or team I’d be working on                              4.8
# Financial performance or funding status of the company or organization     4.7
# Family friendliness                                                        4.3
# Diversity of the company or organization                                   2.8
# Name: JobFactors, dtype: float64

# %%
#nhap
most_job_factor_profession.plot.barh()
plt.title("Đối với lập trình viên chuyên nghiệp")
plt.xlabel("Tỉ lệ %");

# %%
#nhap
most_job_factor_student.plot.barh()
plt.title("Đối với sinh viên đang học code")
plt.xlabel("Tỉ lệ %");

# %%
#nhap
df.MainBranch.unique()
# Out:
# array(['I am a developer by profession',
#        'I am not primarily a developer, but I write code sometimes as part of my work',
#        'I am a student who is learning to code'], dtype=object)

# %%
# - mối liên quan giữa bằng cao nhất và việc coi trọng tấm bằng
# - những ng làm data science sử dụng ngôn ngữ, platform, tool nào
# - với DevType là profession thì họ quan trọng yếu tố nào khi chọn công việc

# %%
#nhap
df = survey_df[['MainBranch', 'EdLevel', 'NEWEdImpt']]
#df = df.dropna()
df
# Out:
#                                                           MainBranch  \
# Respondent
# 1                                     I am a developer by profession
# 2                                     I am a developer by profession
# 3                                        I code primarily as a hobby
# 4                                     I am a developer by profession
# 5           I used to be a developer by profession, but no longer am
# ...                                                              ...
# 64858                                                            NaN
# 64867                                                            NaN
# 64898                                                            NaN
# 64925                                                            NaN
# 65112                                                            NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 64858       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64867                                                   NaN
# 64898                             Primary/elementary school
# 64925                                                   NaN
# 65112            Other doctoral degree (Ph.D., Ed.D., etc.)
#
#                                      NEWEdImpt
# Respondent
# 1                             Fairly important
# 2                             Fairly important
# 3                                          NaN
# 4           Not at all important/not necessary
# 5                               Very important
# ...                                        ...
# 64858                           Very important
# 64867                                      NaN
# 64898                                      NaN
# 64925                                      NaN
# 65112                     Critically important
#
# [63900 rows x 3 columns]

# %%
#nhap
df = df[df.MainBranch=='I am a developer by profession']
df.EdLevel.value_counts(normalize=True)
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.507722
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.252834
# Some college/university study without earning a degree                                0.114315
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.044914
# Associate degree (A.A., A.S., etc.)                                                   0.031997
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.023519
# Professional degree (JD, MD, etc.)                                                    0.013413
# I never completed any formal education                                                0.006423
# Primary/elementary school                                                             0.004864
# Name: EdLevel, dtype: float64

# %%
df.NEWEdImpt.value_counts(normalize=True)
# Out:
# Fairly important                      0.270068
# Very important                        0.242480
# Somewhat important                    0.241125
# Not at all important/not necessary    0.157878
# Critically important                  0.088450
# Name: NEWEdImpt, dtype: float64

# %%
#nhap
df = survey_df[['MainBranch', 'EdLevel', 'NEWEdImpt']]
df = df[df.MainBranch=='I am a student who is learning to code']
df.EdLevel.value_counts(normalize=True)
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          0.328392
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    0.294963
# Some college/university study without earning a degree                                0.199970
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       0.061262
# Primary/elementary school                                                             0.056875
# Associate degree (A.A., A.S., etc.)                                                   0.034942
# I never completed any formal education                                                0.012404
# Professional degree (JD, MD, etc.)                                                    0.006353
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            0.004840
# Name: EdLevel, dtype: float64

# %%
# YOUR CODE HERE
raise NotImplementedError()
